# %%
from selenium.webdriver import Chrome
import requests
from bs4 import BeautifulSoup

driver = Chrome('./chromedriver')

# 開啟ptt主題頁
url = 'https://www.ptt.cc/bbs/index.html'
driver.get(url)
# 找到八卦版的按鈕
driver.find_element_by_class_name('board-name').click()
# 有cookies所以再按按鈕
driver.find_element_by_class_name('btn-big').click()

cookie = driver.get_cookies()

driver.close()

# 設定cookies
ss = requests.session()

for c in cookie:
    ss.cookies.set(c['name'], c['value'])
# 可直接訪問八卦版
res = ss.get('https://www.ptt.cc/bbs/Gossiping/index.html')
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 Gossiping 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/Gossiping/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      Gossiping
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="main-container">
#    <div id="action-bar-container">
#     <div class="action-bar">
#      <div class="btn-group btn-group-dir">
#       <a class="btn selected" href="/bbs/Gossiping/index.html">
#        看板
#       </a>
#       <a class="btn" href="/man/Gossiping/index.html">
#        精華區
#       </a>
#      </div>
#      <div class="btn-group btn-group-paging">
#       <a class="btn wide" href="/bbs/Gossiping/index1.html">
#        最舊
#       </a>
#       <a class="btn wide" href="/bbs/Gossiping/index39089.html">
#        ‹ 上頁
#       </a>
#       <a class="btn wide disabled">
#        下頁 ›
#       </a>
#       <a class="btn wide" href="/bbs/Gossiping/index.html">
#        最新
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="r-list-container action-bar-margin bbs-screen">
#     <div class="search-bar">
#      <form action="search" id="search-bar" type="get">
#       <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
#      </form>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        4
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Gossiping/M.1635920127.A.E31.html">
#        Re: [問卦] 幫！天堂W的角色要取什麼名字？
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Lailungsheng
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%B9%AB%EF%BC%81%E5%A4%A9%E5%A0%82W%E7%9A%84%E8%A7%92%E8%89%B2%E8%A6%81%E5%8F%96%E4%BB%80%E9%BA%BC%E5%90%8D%E5%AD%97%EF%BC%9F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=author%3ALailungsheng">
#           搜尋看板內 Lailungsheng 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       (本文已被刪除) [wester789]
#      </div>
#      <div class="meta">
#       <div class="author">
#        -
#       </div>
#       <div class="article-menu">
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        1
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Gossiping/M.1635920167.A.FD3.html">
#        Re: [問卦] 鬥陣特工（OW）是怎麼下去的？
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        TastyBurger
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E9%AC%A5%E9%99%A3%E7%89%B9%E5%B7%A5%EF%BC%88OW%EF%BC%89%E6%98%AF%E6%80%8E%E9%BA%BC%E4%B8%8B%E5%8E%BB%E7%9A%84%EF%BC%9F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=author%3ATastyBurger">
#           搜尋看板內 TastyBurger 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Gossiping/M.1635920193.A.36C.html">
#        Re: [問卦] 台灣人為什麼都不說敬語？
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        lpbrother
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%8F%B0%E7%81%A3%E4%BA%BA%E7%82%BA%E4%BB%80%E9%BA%BC%E9%83%BD%E4%B8%8D%E8%AA%AA%E6%95%AC%E8%AA%9E%EF%BC%9F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=author%3Alpbrother">
#           搜尋看板內 lpbrother 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        1
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Gossiping/M.1635920208.A.C23.html">
#        [問卦] 橘子跟靜香誰比較正？
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        fm4n3187
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%A9%98%E5%AD%90%E8%B7%9F%E9%9D%9C%E9%A6%99%E8%AA%B0%E6%AF%94%E8%BC%83%E6%AD%A3%EF%BC%9F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=author%3Afm4n3187">
#           搜尋看板內 fm4n3187 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        11/03
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        8
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Gossiping/M.1635920223.A.263.html">
#        [問卦] 欸！女生的男閨蜜是什麼意思？
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        jokerming847
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6