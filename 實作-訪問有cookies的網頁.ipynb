# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36'}
# 詢問cookies的網頁
url_landing_page = 'https://www.ptt.cc/ask/over18?from=%2Fbbs%2FGossiping%2Findex.html'
# 攜帶cookies資訊要post的url
url_tmp = ''
# 得到cookies後要看的頁面
url_index = 'https://www.ptt.cc/bbs/Gossiping/index.html'
# cookies
data = {}


ss = requests.session()

res_landing_page = ss.get(url_landing_page, headers=headers)
soup_landing_page = BeautifulSoup(res_landing_page.text, 'html.parser')
#找到同意的按鈕,得到cookies資料 - "submit"和"hidden"的key&value
button = soup_landing_page.select('button[class="btn-big"]')[0]
# print(button)
button_key = button['name']
# print(button_key)
button_value = button['value']
# print(button_value)

data[button_key] = button_value

hidden = soup_landing_page.select('input')[0]
hidden_key = hidden['name']
hidden_value = hidden['value']
data[hidden_key] = hidden_value

#print(data)

# 在'action'找到接下來要post的網址
url_tmp = 'https://www.ptt.cc' + soup_landing_page.select('form')[0]['action']
#print(url_tmp)

#print(ss.cookies)

ss.post(url_tmp, data=data, headers=headers)

#print(ss.cookies)
# 可直接造訪八卦版
res_index = ss.get(url_index, headers=headers)

print(res_index.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39077.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1635912511.A.6D6.html">Re: [問卦] 大陸超過一半人口沒搭過飛機?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">itmyshit</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%A4%A7%E9%99%B8%E8%B6%85%E9%81%8E%E4%B8%80%E5%8D%8A%E4%BA%BA%E5%8F%A3%E6%B2%92%E6%90%AD%E9%81%8E%E9%A3%9B%E6%A9%9F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aitmyshit">搜尋看板內 itmyshit 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">10</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1635912590.A.7E0.html">[新聞] 助台防禦中國入侵 美參議員提武裝台灣法</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">motan</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E5%8A%A9%E5%8F%B0%E9%98%B2%E7%A6%A6%E4%B8%AD%E5%9C%8B%E5%85%A5%E4%BE%B5&#43;%E7%BE%8E%E5%8F%83%E8%AD%B0%E5%93%A1%E6%8F%90%E6%AD%A6%E8%A3%9D%E5%8F%B0%E7%81%A3%E6%B3%95">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Amotan">搜尋看板內 motan 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1635912626.A.F86.html">Re: [問卦] 「當兵就是學殺人，不道德」怎麼反駁？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Ahhhhaaaa</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E3%80%8C%E7%95%B6%E5%85%B5%E5%B0%B1%E6%98%AF%E5%AD%B8%E6%AE%BA%E4%BA%BA%EF%BC%8C%E4%B8%8D%E9%81%93%E5%BE%B7%E3%80%8D%E6%80%8E%E9%BA%BC%E5%8F%8D%E9%A7%81%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AAhhhhaaaa">搜尋看板內 Ahhhhaaaa 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1635912702.A.B55.html">[問卦] 妹子說：祖先有荷蘭血統。意味？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">rondox</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%A6%B9%E5%AD%90%E8%AA%AA%EF%BC%9A%E7%A5%96%E5%85%88%E6%9C%89%E8%8D%B7%E8%98%AD%E8%A1%80%E7%B5%B1%E3%80%82%E6%84%8F%E5%91%B3%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Arondox">搜尋看板內 rondox 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1620716589.A.F0C.html">[公告] 八卦板板規(2021.05.11)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">arsonlolita</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282021.05.11%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsonlolita">搜尋看板內 arsonlolita 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 5/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">72</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1635573928.A.C75.html">[協尋] 10月29日 觀音大同一路車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">swingingbear</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;10%E6%9C%8829%E6%97%A5&#43;%E8%A7%80%E9%9F%B3%E5%A4%A7%E5%90%8C%E4%B8%80%E8%B7%AF%E8%BB%8A%E7%A6%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aswingingbear">搜尋看板內 swingingbear 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/30</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">25</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1635838952.A.694.html">[公告] 十一月置底閒聊 國父誕辰的十一月</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">wuyiulin</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%8D%81%E4%B8%80%E6%9C%88%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A&#43;%E5%9C%8B%E7%88%B6%E8%AA%95%E8%BE%B0%E7%9A%84%E5%8D%81%E4%B8%80%E6%9C%88">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Awuyiulin">搜尋看板內 wuyiulin 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/02</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>
